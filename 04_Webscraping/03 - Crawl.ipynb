# %% [markdown]
# # Installations
# If you run the code on Colab

# %%
# !pip install selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.0.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.19.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (35.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.5.30)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 252 kB in 2s (104 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (94.0.4606.81-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 68 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %% [markdown]
# If you run this code locally:
# - Install Selenium (via Anaconda)
# - Install the Chrome browser
# - Place the [Chromedriver](https://chromedriver.chromium.org/downloads) into your path (from where you started jupyter)

# %% [markdown]
# # Libraries

# %%
import sys

from bs4 import BeautifulSoup, SoupStrainer
import re

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from pprint import pprint
import random
import time
import unicodedata

# %% [markdown]
# # Selenium

# %%
options = webdriver.ChromeOptions()
## if you run this code locally and want to see how Selenium operates the borwser, comment the following lines
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

## if you run this code locally and want to see how Selenium operates the borwser, uncomment the following line
#options.add_argument("--window-size=1920x1080")

# %% [markdown]
# ## Open a Website

# %%
driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://cfl.lu')

# %% [markdown]
# ## Inspect the DOM
# - Inspect the website source in the browser (F12)

# %%
pprint(driver.page_source)
# Out:
# ('<html class="no-js no-touch" lang="fr"><head>\n'
#  '    <meta charset="utf-8">\n'
#  '    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n'
#  '    <meta name="viewport" content="width=device-width, initial-scale=1, '
#  'maximum-scale=1, user-scalable=no">\n'
#  '    <meta name="format-detection" content="telephone=no">\n'
#  '\n'
#  '    <title>CFL </title>\n'
#  '    <meta name="description" content="CFL - Société nationale des chemins de '
#  'fer luxembourgeois · FR · DE · EN. 2489 2489 Call Center. Votre voyage '
#  'commence ici. ">\n'
#  '\n'
#  '    <link rel="apple-touch-icon" sizes="57x57" '
#  'href="/Content/Images/favicon/apple-icon-57x57.png">\n'
#  '    <link rel="apple-touch-icon" sizes="60x60" '
#  'href="/Content/Images/favicon/apple-icon-60x60.png">\n'
#  '    <link rel="apple-touch-icon" sizes="72x72" '
#  'href="/Content/Images/favicon/apple-icon-72x72.png">\n'
#  '    <link rel="apple-touch-icon" sizes="76x76" '
#  'href="/Content/Images/favicon/apple-icon-76x76.png">\n'
#  '    <link rel="apple-touch-icon" sizes="114x114" '
#  'href="/Content/Images/favicon/apple-icon-114x114.png">\n'
#  '    <link rel="apple-touch-icon" sizes="120x120" '
#  'href="/Content/Images/favicon/apple-icon-120x120.png">\n'
#  '    <link rel="apple-touch-icon" sizes="144x144" '
#  'href="/Content/Images/favicon/apple-icon-144x144.png">\n'
#  '    <link rel="apple-touch-icon" sizes="152x152" '
#  'href="/Content/Images/favicon/apple-icon-152x152.png">\n'
#  '    <link rel="apple-touch-icon" sizes="180x180" '
#  'href="/Content/Images/favicon/apple-icon-180x180.png">\n'
#  '    <link rel="icon" type="image/png" sizes="192x192" '
#  'href="/Content/Images/favicon/android-icon-192x192.png">\n'
#  '    <link rel="icon" type="image/png" sizes="32x32" '
#  'href="/Content/Images/favicon/favicon-32x32.png">\n'
#  '    <link rel="icon" type="image/png" sizes="96x96" '
#  'href="/Content/Images/favicon/favicon-96x96.png">\n'
#  '    <link rel="icon" type="image/png" sizes="16x16" '
#  'href="/Content/Images/favicon/favicon-16x16.png">\n'
#  '    <link rel="manifest" href="/Content/Images/favicon/manifest.json">\n'
#  '    <link rel="stylesheet" href="/Content/Css/voyageurs.css">\n'
#  '    <link rel="stylesheet" '
#  'href="https://use.fontawesome.com/releases/v5.7.2/css/all.css" '
#  'integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" '
#  'crossorigin="anonymous">\n'
#  '    <link rel="alternate" type="application/rss+xml" title="CFL Voyageur '
#  'News - fr" href="http://www.cfl.lu/fr-FR/news/rss">\n'
#  '    <script src="/Scripts/cfl_snazzymaps_style.js"></script>\n'
#  '    <script src="/Scripts/svg4everybody.js"></script>\n'
#  '    <script>svg4everybody();</script>\n'
#  '\n'
#  '    <!-- Google Tag Manager -->\n'
#  '    <script>\n'
#  '\n'
#  '        function getCookie(key) {\n'
#  "            var keyValue = document.cookie.match('(^|;) ?' + key + "
#  "'=([^;]*)(;|$)');\n"
#  '            return keyValue ? keyValue[2] : null;\n'
#  '        }\n'
#  '\n'
#  "        var analytics = getCookie('CFLAnalytics');\n"
#  '        if (analytics) {\n'
#  '            (function(w, d, s, l, i) {\n'
#  '                w[l] = w[l] || [];\n'
#  '                w[l].push({\n'
#  "                    'gtm.start': new Date().getTime(), event: 'gtm.js'\n"
#  '                });\n'
#  '                var f = d.getElementsByTagName(s)[0],\n'
#  '                    j = d.createElement(s),\n'
#  "                    dl = l != 'dataLayer' ? '&l=' + l : '';\n"
#  '                j.async = true;\n'
#  '                j.src =\n'
#  "                    'https://www.googletagmanager.com/gtm.js?id=' + i + dl;\n"
#  '                f.parentNode.insertBefore(j, f);\n'
#  "            })(window, document, 'script', 'dataLayer', 'GTM-T6RT749');\n"
#  '        }\n'
#  '    </script>\n'
#  '    <!-- End Google Tag Manager -->\n'
#  '    <style>\n'
#  '        .js-departure .select2-container--cfl { width: 100px; }\n'
#  '\n'
#  '        .js-arrival .select2-container--cfl { width: 100px; }\n'
#  '        \n'
#  '        .no-header-footer main { padding-top: 0 !important;}\n'
#  '    </style>\n'
#  '    \n'
#  '</head>\n'
#  '<body id="body_id" class="">\n'
#  '\n'
#  '<a href="#content" class="skip-link">Aller au contenu</a>\n'
#  '<a href="#main-nav" class="skip-link">Aller à la navigation principale</a>\n'
#  '\n'
#  '\n'
#  '<style>\n'
#  '  @media (min-width: 769px) { \n'
#  '     \n'
#  '     .header-entity-logo {\n'
#  '     max-width:100px;max-height: 50px;width : auto !important;\n'
#  '     }\n'
#  '     .center-entity-logo {\n'
#  '        text-align: center;\n'
#  '     }\n'
#  '\n'
#  '        }\n'
#  '          @media (min-width: 481px){ \n'
#  '          @media (max-width: 768px){ \n'
#  '          .header-entity-logo {\n'
#  '            max-width:100px;max-height: 40px}\n'
#  '        }}\n'
#  '        @media (max-width: 480px){ \n'
#  '                \n'
#  '            @media (min-width: 375px){ \n'
#  '            .header-entity-logo {\n'
#  '             max-width:50px !important;max-height: 33px}\n'
#  '            }}\n'
#  '            @media (max-width: 375px){ .header-entity-logo {\n'
#  '            max-width:50px !important;max-height: 33px}\n'
#  '             }\n'
#  '</style>\n'
#  '\n'
#  '<header role="banner" class="fixed-top">\n'
#  '    <nav class="bg-light">\n'
#  '        <div class="container-fluid -extended">\n'
#  '            <ul class="nav small nav-sites">\n'
#  '                    <li class="nav-item">\n'
#  '                            <a href="https://www.cfl.lu/fr-FR" '
#  'class="nav-link active internal-link">Voyageurs</a>\n'
#  '                    </li>\n'
#  '                    <li class="nav-item">\n'
#  '                            <a href="https://www.cfl-mm.lu/fr-fr" '
#  'target="_blank" class="nav-link">Fret</a>\n'
#  '                    </li>\n'
#  '                    <li class="nav-item">\n'
#  '                            <a href="https://groupe.cfl.lu" target="_blank" '
#  'class="nav-link">Groupe</a>\n'
#  '                    </li>\n'
#  '            </ul>\n'
#  '        </div>\n'
#  '    </nav>\n'
#  '    <nav class="navbar navbar-main navbar-light navbar-expand-lg border-top '
#  'border-bottom">\n'
#  '        <div class="container-fluid -extended pr-lg-0">\n'
#  '            <a class="navbar-brand center-entity-logo" href="/">\n'
#  '                       <img class="header-entity-logo" '
#  'src="/getattachment/c221c4e8-b389-4fae-85a3-a41f43f8d4dc/logo-75-ans-final-rouge_50_insi-left.svg" '
#  'alt="logo-75-ans-final-rouge_50_INSI-left.svg">\n'
#  '               </a>\n'
#  '            <button class="navbar-toggler" type="button" '
#  'data-toggle="megamenu" data-target="#main-nav" aria-controls="main-nav" '
#  'aria-expanded="false" aria-label="Toggle navigation">\n'
#  '                <span class="tcon tcon-menu--xcross">\n'
#  '                    <span class="tcon-menu__lines"></span>\n'
#  '                </span>\n'
#  '                <span>Menu</span>\n'
#  '            </button>\n'
#  '           \n'
#  '    <div class="navbar-collapse offcanvas-collapse" id="main-nav">\n'
#  '        <div class="navbar-subnav">\n'
#  '            <ul class="navbar-nav">\n'
#  '                <li class="nav-item dropdown language-switcher">\n'
#  '                    <a class="nav-link dropdown-toggle" href="#" '
#  'id="languageSwitcher" role="button" data-toggle="dropdown" '
#  'aria-haspopup="true" aria-expanded="false">\n'
#  '                        FR\n'
#  '                    </a>\n'
#  '                    <div class="dropdown-menu" '
#  'aria-labelledby="languageSwitcher">\n'
#  '\n'
#  '                                <a id="culture-EN" style="cursor: pointer" '
#  'class="dropdown-item" href="#" onclick="location.href=\'/en-gb\' + '
#  'window.location.hash">EN</a>\n'
#  '                                <a id="culture-DE" style="cursor: pointer" '
#  'class="dropdown-item" href="#" onclick="location.href=\'/de-de\' + '
#  'window.location.hash">DE</a>\n'
#  '                    </div>\n'
#  '\n'
#  '                </li>\n'
#  '                <li>\n'
#  '                </li>\n'
#  '            </ul>\n'
#  '\n'
#  '            <button class="btn btn__search px-4 justify-content-center" '
#  'data-toggle="modal" data-target="#searchModal">\n'
#  '                <svg class="icon-03-recherche icon mr-1"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-03-recherche"></use></svg>\n'
#  '            </button>\n'
#  '            <a href="tel:+35224892489" class="bg-primary text-white d-flex '
#  'align-items-center justify-content-center px-3 lead flex-grow-1 '
#  'flex-grow-lg-0">\n'
#  '                <svg class="icon-06-telephone icon mr-2"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-06-telephone"></use></svg>\n'
#  '                2489 2489\n'
#  '            </a>\n'
#  '\n'
#  '        </div>\n'
#  '\n'
#  '        <ul class="navbar-nav mr-auto">\n'
#  '                      <li class="nav-item megamenu ">\n'
#  '                  <a id="nav-link-main-0" class="nav-link megamenu-toggle" '
#  'href="#nav-main-0" data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '                      Préparer mon trajet\n'
#  '                  </a>\n'
#  '              <div class="megamenu-menu" aria-labelledby="nav-link-main-0" '
#  'id="nav-main-0">\n'
#  '                  <div class="container-fluid -extended">\n'
#  '                      <ul class="navbar-nav">\n'
#  '                               <li class="nav-item -back">\n'
#  '         <a class="nav-link megamenu-toggle" href="#nav-main-0" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '            Préparer mon trajet\n'
#  '         </a>\n'
#  '     </li>\n'
#  '\n'
#  '                              <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/timetable">\n'
#  '            Horaires\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/network">\n'
#  '            Réseau &amp; Gares\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/works">\n'
#  '            Travaux\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/disturbances">\n'
#  '            Perturbations\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/customerservices">\n'
#  '            Services clientèle\n'
#  '        </a>\n'
#  '    </li>\n'
#  '\n'
#  '                      </ul>\n'
#  '                  </div>\n'
#  '              </div>\n'
#  '          </li>\n'
#  '          <li class="nav-item megamenu ">\n'
#  '                  <a id="nav-link-main-1" class="nav-link megamenu-toggle" '
#  'href="#nav-main-1" data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '                      Explorer le Luxembourg\n'
#  '                  </a>\n'
#  '              <div class="megamenu-menu" aria-labelledby="nav-link-main-1" '
#  'id="nav-main-1">\n'
#  '                  <div class="container-fluid -extended">\n'
#  '                      <ul class="navbar-nav">\n'
#  '                               <li class="nav-item -back">\n'
#  '         <a class="nav-link megamenu-toggle" href="#nav-main-1" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '            Explorer le Luxembourg\n'
#  '         </a>\n'
#  '     </li>\n'
#  '\n'
#  '                                    <li class="nav-item megamenu ">\n'
#  '                  <a id="nav-link-main-1-0" class="nav-link megamenu-toggle" '
#  'href="/fr-fr/vakanz" data-target="#nav-main-1-0" data-toggle="megamenu" '
#  'role="button" aria-haspopup="true" aria-expanded="false">\n'
#  '                      Régions &amp; Thèmes\n'
#  '                  </a>\n'
#  '              <div class="megamenu-menu" aria-labelledby="nav-link-main-1-0" '
#  'id="nav-main-1-0">\n'
#  '                  <div class="container-fluid -extended">\n'
#  '                      <ul class="navbar-nav">\n'
#  '                               <li class="nav-item -back">\n'
#  '         <a class="nav-link megamenu-toggle" href="#nav-main-1-0" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '            Régions &amp; Thèmes\n'
#  '         </a>\n'
#  '     </li>\n'
#  '\n'
#  '                              <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/vakanz/category/art-et-culture">\n'
#  '            Art &amp; Culture\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" '
#  'href="/fr-fr/vakanz/category/nature-et-excursions">\n'
#  '            Nature &amp; Tours\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/vakanz/category/en-famille">\n'
#  '            Family &amp; Kids\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/vakanz/category/hike-bike">\n'
#  '            Hike &amp; Bike\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/vakanz/category/wellness-food">\n'
#  '            Wellness &amp; Relax\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/vakanz/category/youthhostels">\n'
#  '            Youthhostels.lu\n'
#  '        </a>\n'
#  '    </li>\n'
#  '\n'
#  '                      </ul>\n'
#  '                  </div>\n'
#  '              </div>\n'
#  '          </li>\n'
#  '\n'
#  '                      </ul>\n'
#  '                  </div>\n'
#  '              </div>\n'
#  '          </li>\n'
#  '          <li class="nav-item megamenu ">\n'
#  '                  <a id="nav-link-main-2" class="nav-link megamenu-toggle" '
#  'href="#nav-main-2" data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '                      Réserver &amp; Acheter\n'
#  '                  </a>\n'
#  '              <div class="megamenu-menu" aria-labelledby="nav-link-main-2" '
#  'id="nav-main-2">\n'
#  '                  <div class="container-fluid -extended">\n'
#  '                      <ul class="navbar-nav">\n'
#  '                               <li class="nav-item -back">\n'
#  '         <a class="nav-link megamenu-toggle" href="#nav-main-2" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '            Réserver &amp; Acheter\n'
#  '         </a>\n'
#  '     </li>\n'
#  '\n'
#  '                              <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/ticket">\n'
#  '            Billets\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/subscription">\n'
#  '            Abonnements\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/grouptravel">\n'
#  '            Voyage en groupe\n'
#  '        </a>\n'
#  '    </li>\n'
#  '          <li class="nav-item megamenu ">\n'
#  '                  <a id="nav-link-main-2-3" class="nav-link megamenu-toggle" '
#  'href="/fr-fr/saleschannels" data-target="#nav-main-2-3" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '                      Canaux de vente\n'
#  '                  </a>\n'
#  '              <div class="megamenu-menu" aria-labelledby="nav-link-main-2-3" '
#  'id="nav-main-2-3">\n'
#  '                  <div class="container-fluid -extended">\n'
#  '                      <ul class="navbar-nav">\n'
#  '                               <li class="nav-item -back">\n'
#  '         <a class="nav-link megamenu-toggle" href="#nav-main-2-3" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '            Canaux de vente\n'
#  '         </a>\n'
#  '     </li>\n'
#  '\n'
#  '                              <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/saleschannels/detail/app-mobile">\n'
#  '            Appli mobile\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/saleschannels/detail/en-ligne">\n'
#  '            En ligne\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" '
#  'href="/fr-fr/saleschannels/detail/distributeurs-automatiques">\n'
#  '            Distributeurs automatiques\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/saleschannels/detail/en-gare">\n'
#  '            Centres de vente\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/saleschannels/detail/call-center">\n'
#  '            Callcenter\n'
#  '        </a>\n'
#  '    </li>\n'
#  '\n'
#  '                      </ul>\n'
#  '                  </div>\n'
#  '              </div>\n'
#  '          </li>\n'
#  '          <li class="nav-item megamenu ">\n'
#  '                  <a id="nav-link-main-2-4" class="nav-link megamenu-toggle" '
#  'href="/fr-fr/mobilitysolutions" data-target="#nav-main-2-4" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '                      Solutions de mobilité\n'
#  '                  </a>\n'
#  '              <div class="megamenu-menu" aria-labelledby="nav-link-main-2-4" '
#  'id="nav-main-2-4">\n'
#  '                  <div class="container-fluid -extended">\n'
#  '                      <ul class="navbar-nav">\n'
#  '                               <li class="nav-item -back">\n'
#  '         <a class="nav-link megamenu-toggle" href="#nav-main-2-4" '
#  'data-toggle="megamenu" role="button" aria-haspopup="true" '
#  'aria-expanded="false">\n'
#  '            Solutions de mobilité\n'
#  '         </a>\n'
#  '     </li>\n'
#  '\n'
#  '                              <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/mobilitysolutions/detail/flex">\n'
#  '            Flex\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" '
#  'href="/fr-fr/mobilitysolutions/detail/copilot-klaxit">\n'
#  '            CoPilote\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/mobilitysolutions/detail/velos">\n'
#  '            Vélos\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" '
#  'href="/fr-fr/mobilitysolutions/detail/funiculaire">\n'
#  '            Funiculaire\n'
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/mobilitysolutions/detail/tram">\n'
#  '            Tram\n'
#  '        </a>\n'
#  '    </li>\n'
#  '\n'
#  '                      </ul>\n'
#  '                  </div>\n'
#  '              </div>\n'
#  '          </li>\n'
#  '\n'
#  '                      </ul>\n'
#  '                  </div>\n'
#  '              </div>\n'
#  '          </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/evasion">\n'
#  "            S'évader\n"
#  '        </a>\n'
#  '    </li>\n'
#  '    <li class="nav-item ">\n'
#  '        <a class="nav-link" href="/fr-fr/contact">\n'
#  '            Contacter\n'
#  '        </a>\n'
#  '    </li>\n'
#  '\n'
#  '        </ul>\n'
#  '\n'
#  '    </div>\n'
#  '        </div>\n'
#  '    </nav>\n'
#  '</header>\n'
#  '\n'
#  '<div class="d-none d-print-inline-block print__logo pt-3">\n'
#  '    <img class="header-entity-logo w-100 d-block" '
#  'alt="logo-75-ans-final-rouge_50_INSI-left.svg" '
#  'src="/getattachment/c221c4e8-b389-4fae-85a3-a41f43f8d4dc/logo-75-ans-final-rouge_50_insi-left.svg">\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="modal fade -blurry js-bodyScrolllock modal__search" '
#  'id="searchModal" tabindex="-1" role="dialog" '
#  'aria-labelledby="advancedSearchLabel" aria-hidden="true">\n'
#  '    <div class="modal-dialog" role="document">\n'
#  '        <div class="modal-content h-100  container-fluid">\n'
#  '            <div class="modal-body p-0 h-100">\n'
#  '                <section class="section d-flex justify-content-between '
#  'pb-0">\n'
#  '                    <h3 class="demi">Recherche</h3>\n'
#  '                    <button type="button" class="close btn btn-link -blurry '
#  'py-0 pb-5" data-dismiss="modal">\n'
#  '                        <span class="d-none d-md-block">Fermer</span>\n'
#  '                        <span aria-hidden="true">\n'
#  '                            <svg class="icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-close"></use></svg>\n'
#  '                        </span>\n'
#  '                    </button>\n'
#  '                </section>\n'
#  '                <div class="h-100 d-flex align-items-center">\n'
#  '<form action="/fr-fr/globalsearch" method="get">                        <div '
#  'class="d-flex search-bar-internal align-items-center search-bar-internal">\n'
#  '                            <div class="w-100">\n'
#  '                                <label for="search" '
#  'class="sr-only">Recherche</label>\n'
#  '                                <input type="text" id="search" name="q" '
#  'placeholder="Lancer une recherche" class="search-bar-internal__input '
#  'js-adaptive-font-size-bar form-control px-0 py-2 border-bottom">\n'
#  '                            </div>\n'
#  '                            <button type="submit" class="btn pl-3 '
#  'search-bar-internal__submit">\n'
#  '                                <svg class="icon-03-recherche icon '
#  'text-primary"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-03-recherche"></use></svg>\n'
#  '                            </button>\n'
#  '                        </div>\n'
#  '</form>                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '<script>\n'
#  'var internalLinks = document.getElementsByClassName("nav-link active '
#  'internal-link");\n'
#  'for (var index = 0; index < internalLinks.length; index++)\n'
#  '{\n'
#  '    internalLinks[index].href = internalLinks[index].href + "fr-FR";\n'
#  '}\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="modal fade -blurry js-bodyScrolllock" id="advancedSearch" '
#  'tabindex="-1" role="dialog" aria-labelledby="advancedSearchLabel" '
#  'aria-hidden="true" xmlns="http://www.w3.org/1999/html">\n'
#  '<div class="modal-dialog" role="document">\n'
#  '<div class="modal-content">\n'
#  '<div class="modal-body p-0">\n'
#  '<section class="section advanced-search container-fluid">\n'
#  '<div class="d-flex justify-content-between align-items-center pb-md-5">\n'
#  '    <h3 class="demi">\n'
#  '        Recherche avancée\n'
#  '    </h3>\n'
#  '    <button type="button" class="close btn btn-link -blurry" '
#  'data-dismiss="modal">\n'
#  '        <span class="d-none d-md-block">Fermer</span>\n'
#  '        <span aria-hidden="true">\n'
#  '            <svg class="icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-close"></use></svg>\n'
#  '        </span>\n'
#  '    </button>\n'
#  '</div>\n'
#  '<form class="form border-0 row justify-content-between" '
#  'name="advanced-search" method="get" action="/fr-fr/search/searchresult">\n'
#  '\n'
#  '<div class="col-12">\n'
#  '    <section class="form__locations">\n'
#  '        <div class="form-group dropdown select-autocomplete -centered '
#  '-with-label js-departure">\n'
#  '            <label for="location-departure" aria-hidden="true">de</label>\n'
#  '\n'
#  '            <input type="hidden" name="SearchDepartureExtId" '
#  'id="location-departure-trainID" class="js-trainId">\n'
#  '\n'
#  '            <input id="advancedsearch-departure" type="text" '
#  'name="SearchDeparture" placeholder="Départ" class="form-control js-adress '
#  'js-inputSelect" aria-label="Départ" '
#  'data-url="/fr-fr/search/searchCompletion?root=" aria-haspopup="true" '
#  'aria-expanded="false" autocomplete="new-password">\n'
#  '\n'
#  '            <div class="dropdown-menu" '
#  'aria-labelledby="advancedsearch-departure">\n'
#  '                <h6 class="dropdown-header">Suggestions</h6>\n'
#  '                <ul class="mb-0 select-autocomplete__list js-resultsList" '
#  'data-simplebar="init" data-simplebar-auto-hide="false"><div '
#  'class="simplebar-wrapper" style="margin: 0px 0px 0px -40px;"><div '
#  'class="simplebar-height-auto-observer-wrapper"><div '
#  'class="simplebar-height-auto-observer"></div></div><div '
#  'class="simplebar-mask"><div class="simplebar-offset" style="right: 0px; '
#  'bottom: 0px;"><div class="simplebar-content-wrapper" style="height: auto; '
#  'overflow: hidden;"><div class="simplebar-content" style="padding: 0px 0px '
#  '0px 40px;">\n'
#  '                    <li class="dropdown-item js-selectLoader" '
#  'tabindex="-1">\n'
#  '                        Recherche en cours...\n'
#  '                    </li>\n'
#  '                \n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" data-train-id="9217081">Luxembourg, '
#  'Gare Centrale</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" '
#  'data-train-id="9170001">Esch-sur-Alzette</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" '
#  'data-train-id="9460002">Belval-Université</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" data-train-id="145">Arlon</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" data-train-id="45">Bettembourg</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" '
#  'data-train-id="009441002">Dudelange-Centre</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" '
#  'data-train-id="8200102">Pfaffenthal-Kirchberg</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" data-train-id="9864348">Mersch</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" '
#  'data-train-id="9258199">Ettelbruck</span>\n'
#  '    </li>\n'
#  '\n'
#  '    <li class="js-results dropdown-item d-flex" tabindex="0">\n'
#  '        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '        <span class="js-resultsName" data-train-id="9863323">Rodange</span>\n'
#  '    </li>\n'
#  '</div></div></div></div><div class="simplebar-placeholder" style="width: '
#  '0px; height: 0px;"></div></div><div class="simplebar-track '
#  'simplebar-horizontal" style="visibility: hidden;"><div '
#  'class="simplebar-scrollbar simplebar-visible" style="transform: '
#  'translate3d(0px, 0px, 0px); display: none;"></div></div><div '
#  'class="simplebar-track simplebar-vertical" style="visibility: hidden;"><div '
#  'class="simplebar-scrollbar simplebar-visible" style="transform: '
#  'translate3d(0px, 0px, 0px); display: none;"></div></div></ul>\n'
#  '                <h6 class="dropdown-header">Légende</h6>\n'
#  '                <ul class="mb-0">\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '                        Gare ferroviaire\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon text-green"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-35-bus"></use></svg>\n'
#  '                        Station de bus\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-59-adresse"></use></svg>\n'
#  '                        Adresse\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-poi"></use></svg>\n'
#  '                        POI\n'
#  '                    </li>\n'
#  '                </ul>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '        <div class="form-group dropdown select-autocomplete -centered '
#  '-with-label js-arrival">\n'
#  '            <label for="location-arrival" aria-hidden="true">à</label>\n'
#  '\n'
#  '            <input type="hidden" name="SearchArrivalExtId" '
#  'id="location-arrival-trainID" class="js-trainId">\n'
#  '\n'
#  '            <input id="advancedsearch-arrival" type="text" '
#  'name="SearchArrival" placeholder="Arrivée" class="form-control js-adress '
#  'js-inputSelect" aria-label="Arrivée" '
#  'data-url="/fr-fr/search/searchCompletion?root=" aria-haspopup="true" '
#  'aria-expanded="false" autocomplete="new-password">\n'
#  '\n'
#  '            <div class="dropdown-menu" '
#  'aria-labelledby="advancedsearch-arrival">\n'
#  '                <h6 class="dropdown-header">Suggestions</h6>\n'
#  '                <ul class="mb-0 select-autocomplete__list js-resultsList" '
#  'data-simplebar="init" data-simplebar-auto-hide="false"><div '
#  'class="simplebar-wrapper" style="margin: 0px 0px 0px -40px;"><div '
#  'class="simplebar-height-auto-observer-wrapper"><div '
#  'class="simplebar-height-auto-observer"></div></div><div '
#  'class="simplebar-mask"><div class="simplebar-offset" style="right: 0px; '
#  'bottom: 0px;"><div class="simplebar-content-wrapper" style="height: auto; '
#  'overflow: hidden;"><div class="simplebar-content" style="padding: 0px 0px '
#  '0px 40px;">\n'
#  '                    <li class="dropdown-item js-selectLoader" '
#  'tabindex="-1">\n'
#  '                        Recherche en cours...\n'
#  '                    </li>\n'
#  '                </div></div></div></div><div class="simplebar-placeholder" '
#  'style="width: 0px; height: 0px;"></div></div><div class="simplebar-track '
#  'simplebar-horizontal" style="visibility: hidden;"><div '
#  'class="simplebar-scrollbar simplebar-visible" style="transform: '
#  'translate3d(0px, 0px, 0px); display: none;"></div></div><div '
#  'class="simplebar-track simplebar-vertical" style="visibility: hidden;"><div '
#  'class="simplebar-scrollbar simplebar-visible" style="transform: '
#  'translate3d(0px, 0px, 0px); display: none;"></div></div></ul>\n'
#  '                <h6 class="dropdown-header">Légende</h6>\n'
#  '                <ul class="mb-0">\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '                        Gare ferroviaire\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon text-green"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-35-bus"></use></svg>\n'
#  '                        Station de bus\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-59-adresse"></use></svg>\n'
#  '                        Adresse\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-poi"></use></svg>\n'
#  '                        POI\n'
#  '                    </li>\n'
#  '                </ul>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '        <button class="btn btn-primary btn__switch js-switch-values" '
#  'type="button" data-source="location-departure" '
#  'data-target="location-arrival" aria-label="swap destinations">\n'
#  '            <svg class="icon-07-switch icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-07-switch"></use></svg>\n'
#  '        </button>\n'
#  '    </section>\n'
#  '</div>\n'
#  '\n'
#  '<div class="col-sm-4 col-lg-auto pt-4 mt-sm-3 mt-lg-0">\n'
#  '    <div class="form-group bullet-group js-bullets">\n'
#  '        <div class="custom-control custom-radio">\n'
#  '            <input class="custom-control-input js-departureBullet" '
#  'type="radio" name="departureBullets" value="departure" id="departure-bullet" '
#  'checked="">\n'
#  '            <label class="custom-control-label" '
#  'for="departure-bullet">Départ</label>\n'
#  '        </div>\n'
#  '        <div class="custom-control  custom-radio">\n'
#  '            <input class="custom-control-input js-arrivalBullet" '
#  'type="radio" name="departureBullets" value="arrival" id="arrival-bullet">\n'
#  '            <label class="custom-control-label" '
#  'for="arrival-bullet">Arrivée</label>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '<div class="col-sm-4 col-lg-2">\n'
#  '    <div class="form-group form__time-date js-departureDate '
#  'js-datetimepicker date" data-target-input="nearest" data-date="" '
#  'data-dayformat="DD" data-monthformat="MM" data-yearformat="YYYY" '
#  'data-position="left" data-maxdate="" data-disableddate="" '
#  'id="datepicker-advanced">\n'
#  '        <input type="text" id="form-date-advanced" name="SearchDate" '
#  'class="form-control datetimepicker-input datetimepicker-control" '
#  'data-toggle="datetimepicker" data-target="#datepicker-advanced">\n'
#  '        <label class="form-label datetimepicker-label   pb-0 " '
#  'for="form-date-advanced" data-target="#datepicker-advanced">\n'
#  '            <p class="form-label-title ">Date  </p>\n'
#  '            <div class="d-flex justify-content-between align-items-center '
#  'form-input-container">\n'
#  '                <div class="d-flex align-items-center '
#  'datetimepicker-label">\n'
#  '                    <svg class="form-label-icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-33-calendar"></use></svg>\n'
#  '                    <div class="form-label-date datetimepicker-label">\n'
#  '                        <p class="-montserrat">\n'
#  '                            <span class="date-day">22</span>/<span '
#  'class="date-month">10</span>\n'
#  '                        </p>\n'
#  '                        <p class="-montserrat">\n'
#  '                            <span class="date-week-day">vendredi</span>\n'
#  '                        </p>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '                <svg class="icon-angle-down"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-angle-down"></use></svg>\n'
#  '            </div>\n'
#  '        </label>\n'
#  '    </div>\n'
#  '</div>\n'
#  '\n'
#  '<div class="col-sm-4 col-lg-2">\n'
#  '    <div class="form-group form__time-date js-departureTime '
#  'js-datetimepicker time" data-target-input="nearest" '
#  'id="datepicker-time83001113">\n'
#  '        <label for="form-time-input83001113" class="form-label">\n'
#  '            <p class="form-label-title">Heure</p>\n'
#  '            <div class="d-flex justify-content-between align-items-center '
#  'form-input-container">\n'
#  '                <div class="d-inline-flex align-items-center">\n'
#  '                    <label class="d-flex align-items-center '
#  'datetimepicker-label mb-0" for="form-time-input83001113" '
#  'data-target="#datepicker-time83001113">\n'
#  '                        <svg class="form-label-icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-34-heure"></use></svg>\n'
#  '                    </label>\n'
#  '                    <input type="text" name="SearchTime" '
#  'id="form-time-input83001113" class="datetimepicker-control '
#  'datetimepicker-input" data-target="#datepicker-time83001113" '
#  'data-toggle="datetimepicker">\n'
#  '                </div>\n'
#  '                <svg class="icon-angle-down"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-angle-down"></use></svg>\n'
#  '            </div>\n'
#  '        </label>\n'
#  '    </div>\n'
#  '</div>\n'
#  '<div class="col-lg-5">\n'
#  '    <section class="form-via" id="form-via-section>">\n'
#  '        <div class="form-group dropdown select-autocomplete">\n'
#  '            <label for="form-via" class="">Via</label>\n'
#  '            <input type="hidden" name="SearchViaExtId" '
#  'id="form-via-viaTrainID" class="js-trainId">\n'
#  '            <input id="form-via" type="text" name="SearchVia" '
#  'class="form-control js-adress js-inputSelect" aria-label="Arrivée" '
#  'data-url="/fr-fr/search/searchCompletion?root=" aria-haspopup="true" '
#  'aria-expanded="false" autocomplete="new-password">\n'
#  '\n'
#  '            <div class="dropdown-menu" aria-labelledby="form-via">\n'
#  '                <h6 class="dropdown-header">Suggestions</h6>\n'
#  '                <ul class="mb-0 select-autocomplete__list js-resultsList" '
#  'data-simplebar="init" data-simplebar-auto-hide="false"><div '
#  'class="simplebar-wrapper" style="margin: 0px 0px 0px -40px;"><div '
#  'class="simplebar-height-auto-observer-wrapper"><div '
#  'class="simplebar-height-auto-observer"></div></div><div '
#  'class="simplebar-mask"><div class="simplebar-offset" style="right: 0px; '
#  'bottom: 0px;"><div class="simplebar-content-wrapper" style="height: auto; '
#  'overflow: hidden;"><div class="simplebar-content" style="padding: 0px 0px '
#  '0px 40px;">\n'
#  '                    <li class="dropdown-item js-selectLoader" '
#  'tabindex="-1">\n'
#  '                        Recherche en cours...\n'
#  '                    </li>\n'
#  '                </div></div></div></div><div class="simplebar-placeholder" '
#  'style="width: 0px; height: 0px;"></div></div><div class="simplebar-track '
#  'simplebar-horizontal" style="visibility: hidden;"><div '
#  'class="simplebar-scrollbar simplebar-visible" style="transform: '
#  'translate3d(0px, 0px, 0px); display: none;"></div></div><div '
#  'class="simplebar-track simplebar-vertical" style="visibility: hidden;"><div '
#  'class="simplebar-scrollbar simplebar-visible" style="transform: '
#  'translate3d(0px, 0px, 0px); display: none;"></div></div></ul>\n'
#  '                <h6 class="dropdown-header">Légende</h6>\n'
#  '                <ul class="mb-0">\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '                        Gare ferroviaire\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon text-green"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-35-bus"></use></svg>\n'
#  '                        Station de bus\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-59-adresse"></use></svg>\n'
#  '                        Adresse\n'
#  '                    </li>\n'
#  '                    <li class="dropdown-item legend">\n'
#  '                        <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-poi"></use></svg>\n'
#  '                        POI\n'
#  '                    </li>\n'
#  '                </ul>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '        <btn class="btn btn-link form-via-btn js-addViaBtn">\n'
#  '            <svg class="icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-add"></use></svg>\n'
#  '            <span>ajouter un via</span>\n'
#  '        </btn>\n'
#  '    </section>\n'
#  '\n'
#  '\n'
#  '    \n'
#  '\n'
#  '\n'
#  '    <script id="viaSteps" type="text/html">\n'
#  '        <div class="form-via-step">\n'
#  '            <div class="form-group dropdown select-autocomplete ">\n'
#  '                <label for="form-viaStep" class="">Via</label>\n'
#  '                <input type="hidden" name="SearchViaExtId" '
#  'class="js-trainId" tabindex="-1">\n'
#  '                <input id="form-viaStep"\n'
#  '                       type="text"\n'
#  '                       name="SearchVia"\n'
#  '                       \n'
#  '                       class="form-control js-adress js-inputSelect"\n'
#  '                       aria-label="Arriv&#233;e"\n'
#  '                       data-url="/fr-fr/search/searchCompletion?root="\n'
#  '                       aria-haspopup="true"\n'
#  '                       aria-expanded="false"\n'
#  '                       autocomplete="new-password">\n'
#  '\n'
#  '                <div class="dropdown-menu" aria-labelledby="form-via">\n'
#  '                    <h6 class="dropdown-header">Suggestions</h6>\n'
#  '                    <ul class="mb-0 select-autocomplete__list '
#  'js-resultsList"\n'
#  '                        data-simplebar="init" '
#  'data-simplebar-auto-hide="false">\n'
#  '                        <li class="dropdown-item js-selectLoader" '
#  'tabindex="-1">\n'
#  '                            Recherche en cours...\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                    <h6 class="dropdown-header">L&#233;gende</h6>\n'
#  '                    <ul class="mb-0">\n'
#  '                        <li class="dropdown-item legend">\n'
#  '                            <svg class="mr-2 mt-1 icon text-red"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-24-train"></use></svg>\n'
#  '                            Gare ferroviaire\n'
#  '                        </li>\n'
#  '                        <li class="dropdown-item legend">\n'
#  '                            <svg class="mr-2 mt-1 icon text-green"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-35-bus"></use></svg>\n'
#  '                            Station de bus\n'
#  '                        </li>\n'
#  '                        <li class="dropdown-item legend">\n'
#  '                            <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-59-adresse"></use></svg>\n'
#  '                            Adresse\n'
#  '                        </li>\n'
#  '                        <li class="dropdown-item legend">\n'
#  '                            <svg class="mr-2 mt-1 icon "><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-poi"></use></svg>\n'
#  '                            POI\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '\n'
#  '            <button class="form-via-remove-btn" aria-label="remove via" '
#  'type="button">\n'
#  '                <svg class="icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-close"></use></svg>\n'
#  '            </button>\n'
#  '        </div>\n'
#  '    </script>\n'
#  '\n'
#  '    <script id="viaError" type="text/html">\n'
#  '        <p class="via-error js-error text-red font-size-small">Veuillez '
#  'remplir le champ pr&#233;c&#233;dent</p>\n'
#  '    </script>\n'
#  '\n'
#  '    \n'
#  '    \n'
#  '\n'
#  '</div>\n'
#  '\n'
#  '<div class="col-12 pt-4 pt-lg-5">\n'
#  '    <section class="d-sm-flex flex-wrap flex-lg-nowrap form-options">\n'
#  '        <fieldset>\n'
#  '            <h6 class="-demi">Transports</h6>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="checkbox" name="SearchProducts" value="0" '
#  'class="form-control custom-control-input" id="tgv" checked="">\n'
#  '                    <label class="custom-control-label" for="tgv">\n'
#  '                        TGV / ICE\n'
#  '                    </label>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="form-group">\n'
#  '                            <div class="form-check">\n'
#  '                                <input type="checkbox" name="SearchProducts" '
#  'value="1" class="form-control custom-control-input" id="ic" checked="">\n'
#  '                                <label class="custom-control-label" '
#  'for="ic">\n'
#  '                                    IC\n'
#  '                                </label>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="checkbox" name="SearchProducts" value="3,4" '
#  'class="form-control custom-control-input" id="regionalTrain" checked="">\n'
#  '                    <label class="custom-control-label" '
#  'for="regionalTrain">\n'
#  '                        Trains régionaux\n'
#  '                    </label>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="checkbox" name="SearchProducts" value="2" '
#  'class="form-control custom-control-input" id="bus" checked="">\n'
#  '                    <label class="custom-control-label" for="bus">\n'
#  '                        Bus\n'
#  '                    </label>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="form-group">\n'
#  '                            <div class="form-check">\n'
#  '                                <input type="checkbox" name="SearchProducts" '
#  'value="5" class="form-control custom-control-input" id="Fernbus" '
#  'checked="">\n'
#  '                                <label class="custom-control-label" '
#  'for="Fernbus">\n'
#  '                                    Fernbus\n'
#  '                                </label>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="checkbox" name="SearchProducts" value="8" '
#  'class="form-control custom-control-input" id="tram" checked="">\n'
#  '                    <label class="custom-control-label" for="tram">\n'
#  '                        Tram\n'
#  '                    </label>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="checkbox" name="SearchProducts" value="9" '
#  'class="form-control custom-control-input" id="funicular" checked="">\n'
#  '                    <label class="custom-control-label" for="funicular">\n'
#  '                        Funiculaire\n'
#  '                    </label>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </fieldset>\n'
#  '\n'
#  '        <fieldset>\n'
#  '            <h6 class="-demi">Changements</h6>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="radio" name="SearchMaxConnections" value="" '
#  'class="form-control custom-control-input" id="default" checked="">\n'
#  '                    <label class="custom-control-label" for="default">\n'
#  '                        Nombre quelconque\n'
#  '                    </label>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="form-group">\n'
#  '                <div class="form-check">\n'
#  '                    <input type="radio" name="SearchMaxConnections" '
#  'value="0" class="form-control custom-control-input" id="minimum">\n'
# ...
#  '                            <p>Contactez-nous</p>\n'
#  '                            <svg class="icon-fleche-fat"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-fleche-fat"></use></svg>\n'
#  '                        </a>\n'
#  '                    </div>\n'
#  '                    <div class="col-md-4 d-flex justify-content-md-center '
#  '">\n'
#  '                        <a href="/fr-fr/app/national" class="help__link" '
#  'aria-label="Découvrez l’appli nationale - CFL mobile">\n'
#  '                            <h3 class="mb-0 text-primary js-same-height '
#  'js-heightTrue" style="height: 81px;">Découvrez l’appli nationale - CFL '
#  'mobile</h3>\n'
#  '                            <p>Toutes les infos à tout moment!</p>\n'
#  '                            <svg class="icon-fleche-fat"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-fleche-fat"></use></svg>\n'
#  '                        </a>\n'
#  '                    </div>\n'
#  '                    <div class="col-md-4 d-flex justify-content-md-center '
#  'align-items-md-end">\n'
#  '                        <a href="/fr-fr/app/international" '
#  'class="help__link" aria-label="Découvrez l’appli CFL International">\n'
#  '                            <h3 class="mb-0 text-primary js-same-height '
#  'js-heightTrue" style="height: 81px;">Découvrez l’appli CFL '
#  'International</h3>\n'
#  '                            <p>Toutes les infos à tout moment!</p>\n'
#  '                            <svg class="icon-fleche-fat"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-fleche-fat"></use></svg>\n'
#  '                        </a>\n'
#  '                    </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</section>\n'
#  '\n'
#  '\n'
#  '        <div class="container-fluid  mt-xl-5">\n'
#  '            <div class="row">\n'
#  '                <section class="col-md-7 col-lg-6 col-xl-7">\n'
#  '\n'
#  '                        <ul class="mb-3">\n'
#  '                                <li>\n'
#  '                                    <a href="/fr-fr/news" target="_self">\n'
#  '                                        Actualités\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                                <li>\n'
#  '                                    <a '
#  'href="/fr-fr/withoutbarrier/detail/voyager-sans-barriere" target="_self">\n'
#  '                                        PMR\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                                <li>\n'
#  '                                    <a href="/fr-fr/faq" target="_self">\n'
#  '                                        FAQ\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                                <li>\n'
#  '                                    <a href="/fr-fr/contact" '
#  'target="_self">\n'
#  '                                        Contact\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                                <li>\n'
#  '                                    <a href="/fr-fr/sitemap" '
#  'target="_self">\n'
#  '                                        Plan du site\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                        </ul>\n'
#  '                        <ul class="mb-md-0">\n'
#  '                                <li>\n'
#  '                                    <a '
#  'href="/fr-fr/legalinfos/detail/conditions-legales/8d9964ed-8f25-45ca-9a8c-44be413990f6" '
#  'target="_self">\n'
#  '                                        Conditions légales\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                                <li>\n'
#  '                                    <a '
#  'href="/fr-fr/legalinfos/detail/protection-des-donnees-personnelles/204bf05c-0914-4d0a-a39f-9c966115bf0e" '
#  'target="_self">\n'
#  '                                        Protection des données personnelles\n'
#  '                                    </a>\n'
#  '                                </li>\n'
#  '                        </ul>\n'
#  '                </section>\n'
#  '                <section class="col-md-5 col-lg-6 right col-xl-5">\n'
#  '                    <ul class="social-icons">\n'
#  '                            <li>\n'
#  '                                <a href="http://www.instagram.com/cflinfos" '
#  'aria-label="Instagram" target="_blank">\n'
#  '                                    <svg id="icon-205-instagram" viewBox="0 '
#  '0 512 512" class="icon"><path d="m256 18c131 0 239 107 239 239 0 132-108 '
#  '238-239 238-131 0-238-108-238-239 0-131 107-238 238-238m0-18c-141 0-256 '
#  '115-256 256 0 141 115 256 256 256 141 0 256-115 256-256 '
#  '0-141-115-256-256-256z m54 256c0-30-24-54-54-54-30 0-54 24-54 54 0 30 24 54 '
#  '54 54 30 0 54-24 54-54z m17 0c0 39-32 71-71 71-39 0-71-32-71-71 0-39 32-71 '
#  '71-71 39 0 71 32 71 71z m-133 133c-39 0-71-32-71-71l0-124c0-39 32-71 '
#  '71-71l124 0c39 0 71 32 71 71l0 124c0 39-32 71-71 71z m0-16l124 0c30 0 55-25 '
#  '55-55l0-124c0-30-25-55-55-55l-124 0c-30 0-55 25-55 55l0 124c0 30 25 55 55 '
#  '55z m155-195c0 8-7 16-15 16-8 0-16-8-16-16 0-8 8-15 16-15 9 0 15 6 15 '
#  '15z"></path></svg>\n'
#  '                                </a>\n'
#  '                            </li>\n'
#  '                            <li>\n'
#  '                                <a href="https://blogcfl.lu/fr/accueil" '
#  'aria-label="Wordpress" target="_blank">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'viewBox="0 0 512 512" class="icon"><path d="m375 '
#  '247c0-22-8-37-15-48-9-15-17-27-17-41 0-17 12-31 30-31 1 0 2 0 2 '
#  '0-31-30-73-47-119-47-61 0-116 32-147 79 4 0 8 0 11 0 18 0 47-2 47-2 9-1 10 '
#  '13 1 14 0 0-9 1-21 2l65 191 39-116-28-75c-9-1-18-2-18-2-9-1-8-15 1-14 0 0 28 '
#  '2 46 2 18 0 47-2 47-2 9-1 10 13 1 14 0 0-9 1-20 2l63 189 17-58c9-24 15-42 '
#  '15-57z m36-76c1 5 1 11 1 18 0 18-3 38-14 64l-53 156c52-31 87-87 87-153 '
#  '0-31-8-59-21-85z m-331 85c0 70 40 130 99 159l-84-231c-10 22-15 46-15 72z '
#  'm179 15l-53 154c15 5 33 7 50 7 20 0 40-3 58-10 0-1-1-2-1-2z m-3-253c131 0 '
#  '239 107 239 239 0 132-108 238-239 238-131 0-238-108-238-239 0-131 107-238 '
#  '238-238m0-18c-141 0-256 115-256 256 0 141 115 256 256 256 141 0 256-115 '
#  '256-256 0-141-115-256-256-256z"></path></svg>\n'
#  '                                </a>\n'
#  '                            </li>\n'
#  '                            <li>\n'
#  '                                <a href="https://www.facebook.com/cflinfos" '
#  'aria-label="Facebook" target="_blank">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'viewBox="0 0 512 512" class="icon"><path d="m256 18c131 0 239 107 239 239 0 '
#  '132-108 238-239 238-131 0-238-108-238-239 0-131 107-238 238-238m0-18c-141 '
#  '0-256 115-256 256 0 141 115 256 256 256 141 0 256-115 256-256 '
#  '0-141-115-256-256-256z m40 103c8 0 16 0 25 1 5 0 10 1 15 1l0 50c-1 0-3 0-4 '
#  '0-5 0-11 0-17 0-4 0-8 0-12 0-13 0-22 5-23 21 0 11-1 38-1 39 1 0 13 0 26 0 6 '
#  '0 12 0 18 0 3 0 7 0 10 0-3 18-5 37-7 55l-46 0-1 138-58 0 1-138-47 0 0-54 47 '
#  '0 0-4c0-11 0-23 0-33 0-7 1-14 2-20 3-17 12-31 25-41 12-9 26-13 41-13 3-2 5-2 '
#  '6-2z"></path></svg>\n'
#  '                                </a>\n'
#  '                            </li>\n'
#  '                            <li>\n'
#  '                                <a href="https://twitter.com/cflinfos" '
#  'aria-label="twitter" target="_blank">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'viewBox="0 0 512 512" class="icon"><path d="m256 18c131 0 239 107 239 239 0 '
#  '132-108 238-239 238-131 0-238-108-238-239 0-131 107-238 238-238m0-18c-141 '
#  '0-256 115-256 256 0 141 115 256 256 256 141 0 256-115 256-256 '
#  '0-141-115-256-256-256z m167 154c-2 4-5 7-8 10-7 9-16 16-25 23l-1 2c0 11 0 '
#  '21-1 30-3 22-9 41-17 61-10 19-22 37-37 53-27 26-58 44-94 52-13 3-26 4-38 4-2 '
#  '0-4 0-6 0-37 0-71-10-103-30l-2-1c5 1 10 1 17 1 18 0 34-3 52-10 11-5 22-11 '
#  '33-19-35-1-58-27-63-47 4 1 8 1 12 1 5 0 12-1 17-2l1 '
#  '0c-20-4-34-15-44-31-7-11-11-24-11-36 10 5 20 8 31 '
#  '8-14-10-23-23-27-41-5-17-1-34 8-49 37 43 83 68 140 72 0-3-1-5-1-7-2-17 2-31 '
#  '10-44 12-18 27-28 46-31 4-1 9-1 13-1 17 0 33 7 47 20 1 1 2 1 2 1 0 0 1 0 1 0 '
#  '14-3 27-8 40-15l1 0c-5 15-16 28-29 37 10-3 24-6 36-11z"></path></svg>\n'
#  '                                </a>\n'
#  '                            </li>\n'
#  '                            <li>\n'
#  '                                <a '
#  'href="https://www.linkedin.com/company/cfl-societe-nationale-des-chemins-de-fer-luxembourgeois/" '
#  'aria-label="LinkedIn" target="_blank">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'viewBox="0 0 512 512" class="icon"><path d="m256 18c131 0 239 107 239 239 0 '
#  '132-108 238-239 238-131 0-238-108-238-239 0-131 107-238 238-238m0-18c-141 '
#  '0-256 115-256 256 0 141 115 256 256 256 141 0 256-115 256-256 '
#  '0-141-115-256-256-256z m-92 111c18 0 33 14 32 32 0 18-15 33-33 33-18 '
#  '0-33-14-32-33 0-17 15-32 33-32z m27 90l-1 180-56 0 1-180z m143-4c56 0 66 36 '
#  '66 86l-1 99-56 0 1-88c0-21 0-48-29-48-28 0-33 22-33 46l-1 89-56 0 1-180 54 0 '
#  '0 24 1 0c8-14 26-28 53-28z"></path></svg>\n'
#  '                                </a>\n'
#  '                            </li>\n'
#  '                            <li>\n'
#  '                                <a '
#  'href="https://www.youtube.com/channel/UCbILtSGsmbIERRwuaSpevXQ/feed" '
#  'aria-label="Youtube" target="_blank">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'viewBox="0 0 512 512" class="icon"><path d="m256 17c131 0 239 107 239 239 0 '
#  '132-108 238-239 238-131 0-238-107-238-239 0-132 107-238 238-238m0-18c-141 '
#  '0-256 115-256 256 0 141 115 256 256 256 141 0 256-115 256-256 '
#  '0-141-115-256-256-256z m142 179c11 29 11 131-3 158-3 7-9 12-16 16-10 5-69 '
#  '7-126 7-52 0-105-2-117-6-11-4-18-11-22-22-10-28-13-142 7-164 6-7 15-12 24-13 '
#  '23-2 68-4 111-4 54 0 108 2 118 5 12 5 20 12 24 23z m-179 122c31-16 62-32 '
#  '93-48-30-16-61-33-92-48-1 33-1 64-1 96"></path></svg>\n'
#  '                                </a>\n'
#  '                            </li>\n'
#  '                    </ul>\n'
#  '                                    <a href="https://groupe.cfl.lu/fr-fr" '
#  'target="_blank" aria-label="CFL" class="footer__logo">\n'
#  '                                        <img '
#  'src="/getattachment/0d52c846-9621-45f0-874f-91b65df5c06f/whitebox_bg.svg" '
#  'alt="whitebox_bg.svg">\n'
#  '                                    </a>\n'
#  '                </section>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </footer>\n'
#  '\n'
#  '<!-- Scripts -->\n'
#  '        <script src="/Scripts/voyageurs.js"></script>\n'
#  '\n'
#  '\n'
#  '  <script src="/Scripts/searchTrip.js"></script>\n'
#  '\n'
#  '\n'
#  '<div id="cookies-notice" class="bg-primary text-white pt-5 pb-4  '
#  'cookies-notice__wrapper js-cookie-notice" style="visibility: visible;" '
#  'data-start-id="homeDiscoverTab" data-end-id="footer">\n'
#  '    <div class="container-fluid">\n'
#  '        <div class="d-md-flex align-items-center justify-content-between">\n'
#  '            <div>\n'
#  '                <p class="cookies-notice__text">\n'
#  '                    Les cookies sont des fichiers déposés sur vos appareils '
#  '(ordinateur, mobile) afin de nous permettre de collecter des informations '
#  'relatives à votre navigation.\n'
#  '                </p>\n'
#  '                <p class="cookies-notice__text mt-3 mt-lg-0">\n'
#  '                    Si vous poursuivez votre navigation sur notre site, vous '
#  'acceptez l’utilisation des cookies à des fins de statistiques.&nbsp;\n'
#  '\n'
#  '                        <a '
#  'href="/getattachment/c3c85114-fb94-4b5d-9f1d-3dd0451117f8/2019-09-09-notice-d-information-sur-les-cookies_voyageurs_fr.pdf" '
#  'target="_blank" class="text-white underlined__arrow mt-0">\n'
#  '                             Pour en savoir plus sur nos cookies.\n'
#  '                                                                                                               '
#  '</a>\n'
#  '                </p>\n'
#  '                <form class="d-md-flex form border-0 pt-4">\n'
#  '                    <div class="form-group">\n'
#  '                        <div class="form-check pr-4">\n'
#  '                            <input type="checkbox" class="form-control '
#  'custom-control-input -inversed" id="technicalCookie" name="technicalCookie" '
#  'checked="" disabled="">\n'
#  '                            <label class="custom-control-label" '
#  'for="technicalCookie">\n'
#  '                                Cookies techniques\n'
#  '                            </label>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '\n'
#  '                    <div class="form-group pr-4">\n'
#  '                        <div class="form-check">\n'
#  '                            <input type="checkbox" class="form-control '
#  'custom-control-input -inversed" id="statisticalCookie" '
#  'name="statisticalCookie" checked="">\n'
#  '                            <label class="custom-control-label" '
#  'for="statisticalCookie">\n'
#  '                                Cookies statistiques\n'
#  '                            </label>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                </form>\n'
#  '            </div>\n'
#  '            <a onclick="acceptCookies()" class="btn btn-primary btn__arrow '
#  'border-white cookies-notice__btn js-cookie-handler mt-md-0 mt-3 ml-md-4">\n'
#  "                J'accepte\n"
#  '                <svg class="icon"><use '
#  'xlink:href="/Content/Images/svg/icons.svg#icon-12-fleche"></use></svg>\n'
#  '            </a>\n'
#  '\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '<script>\n'
#  '\n'
#  '    // Create cookie\n'
#  '    function createCookie(name, value, days) {\n'
#  '        var expires;\n'
#  '        if (days) {\n'
#  '            var d = new Date();\n'
#  '            var year = d.getFullYear();\n'
#  '            var month = d.getMonth();\n'
#  '            var day = d.getDate();\n'
#  '            var date = new Date(year + 1, month, day);/*\n'
#  '            var date = new Date();\n'
#  '            date.setTime(date.getTime()+(days*24*60*60*1000));*/\n'
#  '            expires = "; expires="+date.toUTCString();\n'
#  '        }\n'
#  '        else {\n'
#  '            expires = "";\n'
#  '        }\n'
#  '        document.cookie = name + "=" + value + expires + "; path=/";\n'
#  '    }\n'
#  '\n'
#  '// Read cookie\n'
#  '    function readCookie(name) {\n'
#  '        var nameEQ = name + "=";\n'
#  "        var ca = document.cookie.split(';');\n"
#  '        for(var i=0;i < ca.length;i++) {\n'
#  '            var c = ca[i];\n'
#  "            while (c.charAt(0) === ' ') {\n"
#  '                c = c.substring(1,c.length);\n'
#  '            }\n'
#  '            if (c.indexOf(nameEQ) === 0) {\n'
#  '                return c.substring(nameEQ.length,c.length);\n'
#  '            }\n'
#  '        }\n'
#  '        return null;\n'
#  '    }\n'
#  '\n'
#  '// Erase cookie\n'
#  '    function eraseCookie(name) {\n'
#  '        createCookie(name,"",-1);\n'
#  '    }\n'
#  '    \n'
#  "    var technical = getCookie('CFLTechnical');\n"
#  '\n'
#  '    if (!technical) {\n'
#  "        document.getElementById('cookies-notice').style.visibility = "
#  "'visible';\n"
#  '    }\n'
#  '\n'
#  '    function acceptCookies() {\n'
#  '        /*document.cookie =\n'
#  '            "CFLTechnical= Fri, 22 Oct 2021 02:20:45 GMT;expires=Sat, 22 Oct '
#  '2022 02:20:45 GMT;path=/;domain=www.cfl.lu";*/\n'
#  '        createCookie("CFLTechnical", "22/10/2021 04:20:45", 365);\n'
#  '        if (document.getElementById("statisticalCookie").checked) {\n'
#  '            /*document.cookie =\n'
#  '                "CFLAnalytics= Fri, 22 Oct 2021 02:20:45 GMT;expires=Sat, 22 '
#  'Oct 2022 02:20:45 GMT;path=/;domain=www.cfl.lu";*/\n'
#  '            createCookie("CFLAnalytics", "22/10/2021 04:20:45", 365);\n'
#  '        }\n'
#  '    }\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '\n'
#  '</body></html>')

# %% [markdown]
# ## Find Elements

# %% [markdown]
# ### by XPATH

# %%
el = driver.find_element(by=By.XPATH, value='//a[contains(@onclick, "accept")]')
print(el.tag_name)

el.click()
# Out:
# a

# %% [markdown]
# ### by ID

# %%
el = driver.find_element(by=By.ID, value='quicksearch-departure')
print(el.tag_name)

el.clear()
el.send_keys('Luxembourg')
el.send_keys(Keys.RETURN)
# Out:
# input

# %%
el = driver.find_element(by=By.ID, value='quicksearch-arrival')
print(el.tag_name)

el.clear()
el.send_keys('Belval-Université')
el.send_keys(Keys.RETURN)
# Out:
# input

# %% [markdown]
# ## Build Soup from HTML

# %%
soup = BeautifulSoup(driver.page_source,
                     parse_only=SoupStrainer('div', attrs={'class': 'search__head'}))

# %%
print(soup.prettify())
# Out:
# <div class="search__head">
#  <div class="search__hours-container">
#   <p class="search__hours">
#    <span class="js-departure-hour">
#     05:02
#    </span>
#   </p>
#   <svg class="icon__arrow">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-arrow-right-1">
#    </use>
#   </svg>
#   <p class="search__hours">
#    <span class="js-arrival-hour">
#     05:32
#    </span>
#   </p>
#  </div>
#  <div class="search__stop-info order-md-3" data-original-title="Arrêts trains modifiés!" data-toggle="tooltip" data-trigger="hover focus" title="">
#   <svg class="icon">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-info">
#    </use>
#   </svg>
#  </div>
#  <div class="search__head-infos">
#   <div class="search__head-inner">
#    <p class="search__duration">
#     <svg class="icon">
#      <use xlink:href="/Content/Images/svg/icons.svg#icon-34-heure">
#      </use>
#     </svg>
#     <span class="js-travel-time">
#      00:30
#     </span>
#    </p>
#   </div>
#   <p class="search__connections-number">
#    Pas de changement
#   </p>
#  </div>
# </div>
# <div class="search__head">
#  <div class="search__hours-container">
#   <p class="search__hours">
#    <span class="js-departure-hour">
#     05:21
#    </span>
#   </p>
#   <svg class="icon__arrow">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-arrow-right-1">
#    </use>
#   </svg>
#   <p class="search__hours">
#    <span class="js-arrival-hour">
#     05:49
#    </span>
#   </p>
#  </div>
#  <div class="search__head-infos">
#   <div class="search__head-inner">
#    <p class="search__duration">
#     <svg class="icon">
#      <use xlink:href="/Content/Images/svg/icons.svg#icon-34-heure">
#      </use>
#     </svg>
#     <span class="js-travel-time">
#      00:28
#     </span>
#    </p>
#   </div>
#   <p class="search__connections-number">
#    Pas de changement
#   </p>
#  </div>
# </div>
# <div class="search__head">
#  <div class="search__hours-container">
#   <p class="search__hours">
#    <span class="js-departure-hour">
#     05:32
#    </span>
#   </p>
#   <svg class="icon__arrow">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-arrow-right-1">
#    </use>
#   </svg>
#   <p class="search__hours">
#    <span class="js-arrival-hour">
#     06:02
#    </span>
#   </p>
#  </div>
#  <div class="search__stop-info order-md-3" data-original-title="Arrêts trains modifiés!" data-toggle="tooltip" data-trigger="hover focus" title="">
#   <svg class="icon">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-info">
#    </use>
#   </svg>
#  </div>
#  <div class="search__head-infos">
#   <div class="search__head-inner">
#    <p class="search__duration">
#     <svg class="icon">
#      <use xlink:href="/Content/Images/svg/icons.svg#icon-34-heure">
#      </use>
#     </svg>
#     <span class="js-travel-time">
#      00:30
#     </span>
#    </p>
#   </div>
#   <p class="search__connections-number">
#    Pas de changement
#   </p>
#  </div>
# </div>
# <div class="search__head">
#  <div class="search__hours-container">
#   <p class="search__hours">
#    <span class="js-departure-hour">
#     05:51
#    </span>
#   </p>
#   <svg class="icon__arrow">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-arrow-right-1">
#    </use>
#   </svg>
#   <p class="search__hours">
#    <span class="js-arrival-hour">
#     06:19
#    </span>
#   </p>
#  </div>
#  <div class="search__head-infos">
#   <div class="search__head-inner">
#    <p class="search__duration">
#     <svg class="icon">
#      <use xlink:href="/Content/Images/svg/icons.svg#icon-34-heure">
#      </use>
#     </svg>
#     <span class="js-travel-time">
#      00:28
#     </span>
#    </p>
#   </div>
#   <p class="search__connections-number">
#    Pas de changement
#   </p>
#  </div>
# </div>
# <div class="search__head">
#  <div class="search__hours-container">
#   <p class="search__hours">
#    <span class="js-departure-hour">
#     06:02
#    </span>
#   </p>
#   <svg class="icon__arrow">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-arrow-right-1">
#    </use>
#   </svg>
#   <p class="search__hours">
#    <span class="js-arrival-hour">
#     06:32
#    </span>
#   </p>
#  </div>
#  <div class="search__stop-info order-md-3" data-original-title="Arrêts trains modifiés!" data-toggle="tooltip" data-trigger="hover focus" title="">
#   <svg class="icon">
#    <use xlink:href="/Content/Images/svg/icons.svg#icon-info">
#    </use>
#   </svg>
#  </div>
#  <div class="search__head-infos">
#   <div class="search__head-inner">
#    <p class="search__duration">
#     <svg class="icon">
#      <use xlink:href="/Content/Images/svg/icons.svg#icon-34-heure">
#      </use>
#     </svg>
#     <span class="js-travel-time">
#      00:30
#     </span>
#    </p>
#   </div>
#   <p class="search__connections-number">
#    Pas de changement
#   </p>
#  </div>
# </div>

# %% [markdown]
# ## Extract Information

# %%
print('The next trains from Luxembourg to Belval-Université leave at:')
set(sorted([train.string.strip() for train in soup.find_all('span', attrs={'js-departure-hour'})]))
# Out:
# The next trains from Luxembourg to Belval-Université leave at:
# {'05:02', '05:21', '05:32', '05:51', '06:02'}

# %% [markdown]
# ## ❓ Exercise
# Get more connections:
# - Locate the button that loads more connections on www.cfl.lu
# - Click on it (el.click)
# - Wait for 5 seconds for the website to load (time.sleep(5))
# - Scrape the resulting page
# - Parse the HTML and extract the departure times

# %% [markdown]
# ## Close the Browser

# %%
driver.quit()

# %% [markdown]
# # Eurostat Quiz

# %%
# %%html
# <iframe src="https://ec.europa.eu/eurostat/cache/quiz/?lang=en" width="100%"/ height='800'>
# Out:
# <iframe src="https://ec.europa.eu/eurostat/cache/quiz/?lang=en" width="100%"/ height='800'>

# %% [markdown]
# ## Navigate to page

# %%
driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://ec.europa.eu/eurostat/cache/quiz/?lang=en')

# %% [markdown]
# ## Accept Cookies

# %%
el = driver.find_element(by=By.XPATH, value='//a[contains(@href, "refuse")]')
el.click()
el = driver.find_element(by=By.XPATH, value='//a[contains(@href, "close")]')
el.click()

# %% [markdown]
# ## Start Game

# %%
el = driver.find_element(by=By.XPATH, value='//button[contains(@ng-show, "showplay")]')
el.click()

# %% [markdown]
# ## Select Question

# %%
els = driver.find_elements(by=By.XPATH, value='//a[contains(@class, "question") and not(contains(@class, "answered"))]')
el = random.sample(els, 1)[0]
el.click()

# %% [markdown]
# ## ❓ Exercise
#
# Extract the quiz data

# %%
soup = BeautifulSoup(driver.page_source, 
                     parse_only=SoupStrainer('div', attrs={'class': 'modal-dialog'}))

# %%
print(soup.prettify())
# Out:
# <div class="modal-dialog">
#  <div class="modal-content theme-4" ng-class="{ 'wrong animated shake': wrongClass, 'correct animated bounceIn': correctClass }">
#   <div class="modal-body" ng-show="choiceansw">
#    <div class="title">
#     <img alt="" ng-src="images/themes/theme4w.png" src="images/themes/theme4w.png"/>
#     <span class="ng-binding" ng-bind="themeTitle | decodeURIComponent">
#      In­dus­try, trade and ser­vices
#     </span>
#    </div>
#    <p class="ng-binding" ng-bind="questionText | decodeURIComponent">
#     Which country has the highest number of small and medium enterprises (SME) in manufacturing?
#    </p>
#    <form class="ng-pristine ng-valid" role="form">
#     <div class="radio">
#      <input class="ng-pristine ng-untouched ng-valid ng-empty" id="theme-4-Germany" name="quiz-radio" ng-model="choice.value" type="radio" value="1"/>
#      <label class="ng-binding" for="theme-4-Germany">
#       Germany
#      </label>
#     </div>
#     <div class="radio">
#      <input class="ng-pristine ng-untouched ng-valid ng-empty" id="theme-4-Italy" name="quiz-radio" ng-model="choice.value" type="radio" value="2"/>
#      <label class="ng-binding" for="theme-4-Italy">
#       Italy
#      </label>
#     </div>
#     <div class="radio">
#      <input class="ng-pristine ng-untouched ng-valid ng-empty" id="theme-4-Czechia" name="quiz-radio" ng-model="choice.value" type="radio" value="3"/>
#      <label class="ng-binding" for="theme-4-Czechia">
#       Czechia
#      </label>
#     </div>
#    </form>
#    <div class="action">
#     <button class="btn-bold ng-binding" data-id="4" data-theme="4" ng-click="checkAnsw($event)" type="button">
#      Submit
#     </button>
#    </div>
#   </div>
#   <div class="modal-body modal-feedback text-center ng-hide" ng-show="choiceresyes">
#    <h3 class="ng-binding">
#     <img alt="Correct answer" src="images/icon-correct.png"/>
#     <br/>
#     Correct
#    </h3>
#    <br/>
#    <p class="pad-bot space-hbot ng-binding" ng-bind="questionMsg | decodeURIComponent">
#     Italy (376 343 SME) has the highest number of SMEs (from 1 to 249 persons employed) in manufacturing (Germany 201 633, Czechia 179 304).
#    </p>
#    <div class="pad-bot space-bot">
#     <button class="btn-bold ng-binding" ng-click="hideModalQCheck()" type="button">
#      Continue
#     </button>
#    </div>
#   </div>
#   <div class="modal-body modal-feedback text-center ng-hide" ng-show="choiceresno">
#    <h3 class="ng-binding">
#     <img alt="Wrong answer" src="images/icon-wrong.png"/>
#     <br/>
#     Wrong
#    </h3>
#    <br/>
#    <p class="pad-bot space-hbot ng-binding" ng-bind="questionMsg | decodeURIComponent">
#     Italy (376 343 SME) has the highest number of SMEs (from 1 to 249 persons employed) in manufacturing (Germany 201 633, Czechia 179 304).
#    </p>
#    <div class="pad-bot space-bot">
#     <button class="btn-bold ng-binding" ng-click="hideModalQCheck()" type="button">
#      Continue
#     </button>
#    </div>
#   </div>
#  </div>
# </div>

# %% [markdown]
# ### Category

# %%
#category = ...

# %% [markdown]
# ### Question

# %%
# question = ...

# %% [markdown]
# ### Choices

# %%
# choices = [...]

# %% [markdown]
# ### Answer

# %%
# answer = ...

# %% [markdown]
# ## Select Answer

# %%
els = driver.find_elements(by=By.TAG_NAME, value='input')
el = random.sample(els, 1)[0]
el.click()

# %% [markdown]
# ## Submit Answer

# %%
el = driver.find_element(by=By.XPATH, value='//button[contains(., "Submit")]')
el.click()

# %% [markdown]
# ## Continue

# %%
try:
    el = driver.find_element(by=By.XPATH, value='//div[3]/div/button')
    el.click()
except:
    el = driver.find_element(by=By.XPATH, value='//div[2]/div/button')
    el.click()

# %% [markdown]
# # Loop

# %%
quiz = []

# load the quiz site
driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://ec.europa.eu/eurostat/cache/quiz/?lang=en')
driver.implicitly_wait(1)

# accept cookies
el = driver.find_element(by=By.XPATH, value='//a[contains(@href, "refuse")]')
el.click()
el = driver.find_element(by=By.XPATH, value='//a[contains(@href, "close")]')
el.click()
driver.implicitly_wait(2)

# start the game
el = driver.find_element(by=By.XPATH, value='//button[contains(@ng-show, "showplay")]')
el.click()

remaining_questions = 9
while remaining_questions:
    
    # select a question
    els = driver.find_elements(by=By.XPATH, value='//a[contains(@class, "question") and not(contains(@class, "answered"))]')
    el = random.sample(els, 1)[0]
    el.click()
    driver.implicitly_wait(1)
    
    # scrape the question
    soup = BeautifulSoup(driver.page_source, 
                     parse_only=SoupStrainer('div', attrs={'class': 'modal-dialog'}))
    category = soup.find('div', attrs={'class':'title'}).find('span').text.replace('\xad','')
    question = soup.find('p', attrs={'ng-bind': re.compile('questionText ')}).text
    choices = list(map(lambda l : l.text.strip(), soup.select('div.radio > label')))
    answer = soup.find(attrs={'ng-bind': re.compile('questionMsg')}).text.replace('\xad','')
    quiz.append({
        'category': category,
        'question': question,
        'choices': choices,
        'answer': answer
    })
    
    # select an answer
    els = driver.find_elements(by=By.TAG_NAME, value='input')
    el = random.sample(els, 1)[0]
    el.click()
    driver.implicitly_wait(1)
    
    # submit answer
    el = driver.find_element(by=By.XPATH, value='//button[contains(., "Submit")]')
    el.click()
    driver.implicitly_wait(1)
    
    # continue to next question
    try:
        el = driver.find_element(by=By.XPATH, value='//div[2]/div/button')
        el.click()
    except:
        el = driver.find_element(by=By.XPATH, value='//div[3]/div/button')
        el.click()
    driver.implicitly_wait(1)
    
    els = driver.find_elements(by=By.XPATH, value='//a[contains(@class, "question") and not(contains(@class, "answered"))]')
    remaining_questions = len(els)

# %%
pprint(quiz)
# Out:
# [{'answer': 'Romania (+27%) has the highest growth rate of production in '
#             'construction (Hungary +21%, Cyprus +12%).',
#   'category': 'Industry, trade and services',
#   'choices': ['Romania', 'Cyprus', 'Hungary'],
#   'question': 'Which country has the highest annual growth rate of production '
#               'in construction?'},
#  {'answer': 'Luxembourg (676 cars per 1 000 inhabitants) has the largest '
#             'number (Cyprus 629, Slovenia 549).',
#   'category': 'Transport',
#   'choices': ['Luxembourg', 'Cyprus', 'Slovenia'],
#   'question': 'Which country has most cars per inhabitant?'},
#  {'answer': 'Sweden (28.0 million hectares) has the largest forest area '
#             '(Finland 22.4 mn ha, Spain 18.6 mn ha).',
#   'category': 'Agriculture and fisheries',
#   'choices': ['Finland', 'Sweden', 'Spain'],
#   'question': 'Which country has the largest forest area?'},
#  {'answer': 'Netherlands (59%) has the highest share of households living in '
#             'cities (Cyprus 52%, Portugal 46%).',
#   'category': 'Population and social conditions',
#   'choices': ['Portugal', 'Cyprus', 'Netherlands'],
#   'question': 'Which country has the highest share of households living in '
#               'cities?'},
#  {'answer': 'Italy (135 694 persons) grants the highest number of citizenships '
#             'to foreigners (Germany 85 350, Greece 27 104).',
#   'category': 'Population and social conditions',
#   'choices': ['Italy', 'Germany', 'Greece'],
#   'question': 'Which country grants the highest number of citizenships to '
#               'foreigners?'},
#  {'answer': 'Amsterdam Schiphol (32 million passengers handled) is the busiest '
#             'passenger airport (Frankfurt/Main 28 mn, Paris/Charles de Gaulle '
#             '26 mn).',
#   'category': 'Transport',
#   'choices': ['Paris/Charles de Gaulle (France)',
#               'Frankfurt/Main (Germany)',
#               'Amsterdam/Schiphol (Netherlands)'],
#   'question': 'Which airport is the busiest in terms of passengers handled '
#               'within the EU?'},
#  {'answer': 'Finland (79% of individuals) has the highest share of people '
#             'watching Internet streamed TV (Malta 49%, Portugal 34%).',
#   'category': 'Science and technology',
#   'choices': ['Malta', 'Finland', 'Portugal'],
#   'question': 'In which country is Internet streamed TV most popular?'},
#  {'answer': 'Imports from China account for 14% of Euro area imports of goods.',
#   'category': 'International trade',
#   'choices': ['China', 'USA', 'Switzerland'],
#   'question': 'The main partner for Euro area imports of goods is:'},
#  {'answer': 'Sweden (56%) has the highest share of renewables in gross final '
#             'energy consumption (Latvia 41%, Denmark 37%).',
#   'category': 'Environment and energy',
#   'choices': ['Latvia', 'Denmark', 'Sweden'],
#   'question': 'Which country has the highest share of renewable energy in '
#               'gross final energy consumption?'},
#  {'answer': 'Nearly 75 million young people (15-29 years) live in the EU.',
#   'category': 'Population and social conditions',
#   'choices': ['75 million',
#               'Between 50 and 75 million',
#               'Less than 50 million'],
#   'question': 'Approximately how many young people live in the EU?'},
#  {'answer': 'Spain (55.9 million heads) has the largest livestock population '
#             '(Germany 39.3 mn, Romania 17.7 mn).',
#   'category': 'Agriculture and fisheries',
#   'choices': ['Germany', 'Spain', 'Romania'],
#   'question': 'Which country has the largest livestock population?'},
#  {'answer': 'Denmark (844 kg per inhabitant) has the highest amount of '
#             'municipal waste generated (Malta 694 kg, Slovenia 504 kg).',
#   'category': 'Environment and energy',
#   'choices': ['Malta', 'Slovenia', 'Denmark'],
#   'question': 'Which country has the highest amount of municipal waste '
#               'generated per inhabitant?'},
#  {'answer': 'Canarias (96.1 million nights spent by tourists) is the leading '
#             'tourist region (Jadranska Hrvatska 86.2, Île de France 84.7).',
#   'category': 'General statistics',
#   'choices': ['Île-de-France (France)',
#               'Jadranska Hrvatska (Croatia)',
#               'Canarias (Spain)'],
#   'question': 'Which is the most popular tourist destination?'},
#  {'answer': 'Italy (376 343 SME) has the highest number of SMEs (from 1 to 249 '
#             'persons employed) in manufacturing (Germany 201 633, Czechia 179 '
#             '304).',
#   'category': 'Industry, trade and services',
#   'choices': ['Germany', 'Italy', 'Czechia'],
#   'question': 'Which country has the highest number of small and medium '
#               'enterprises (SME) in manufacturing?'},
#  {'answer': 'Malta (95% of all nights spent by tourists) records the highest '
#             'share (Luxembourg  88%, Austria 71%).',
#   'category': 'Industry, trade and services',
#   'choices': ['Luxembourg', 'Malta', 'Austria'],
#   'question': 'Which country records the highest share of nights spent by '
#               'foreign tourists in tourist accommodation establishments?'},
#  {'answer': 'Sostinės regionas (56%) has the highest share of people (% of '
#             'population aged 20-64 years) with tertiary education (Prov. '
#             'Antwerpen 40%, Swietokrzyskie 30%).',
#   'category': 'General statistics',
#   'choices': ['Prov. Antwerpen (Belgium)',
#               'Sostinės regionas (Lithuania)',
#               'Swietokrzyskie (Poland)'],
#   'question': 'Which region has the highest share of people with tertiary '
#               'education?'},
#  {'answer': 'The Netherlands (37% of individuals) has the highest share of '
#             'people selling goods or services online (Estonia 21%, Poland '
#             '12%).',
#   'category': 'Science and technology',
#   'choices': ['Netherlands', 'Estonia', 'Poland'],
#   'question': 'Which country has the highest share of people using internet '
#               'for selling goods and services?'},
#  {'answer': 'Poland (3.7%) has the highest inflation rate (Slovakia 2%, Malta '
#             '0.8%).',
#   'category': 'Economy and finance',
#   'choices': ['Slovakia', 'Malta', 'Poland'],
#   'question': 'Which country has the highest inflation rate?'},
#  {'answer': 'Brazil is the largest trading partner of goods of the EU among '
#             'South American countries.',
#   'category': 'International trade',
#   'choices': ['Argentina', 'Brazil', 'Chile'],
#   'question': 'Among South American countries, which one is the EU’s largest '
#               'trading partner?'},
#  {'answer': 'Ciudad de Ceuta (832 doctors) has the highest number of doctors '
#             'per 100 000 inhabitants (Attiki  792, Bratislavský kraj 644).',
#   'category': 'General statistics',
#   'choices': ['Attiki (Greece)',
#               'Bratislavský kraj (Slovakia)',
#               'Ciudad de Ceuta (Spain)'],
#   'question': 'Which region has the highest number of doctors per 100 000 '
#               'inhabitants?'},
#  {'answer': 'Sweden (3.4%) has the highest R&D expenditure in % of GDP (France '
#             '2.2%, Romania 0.5%).',
#   'category': 'Science and technology',
#   'choices': ['Sweden', 'France', 'Romania'],
#   'question': 'Which country has the highest total expenditure for research '
#               'and development (R&D) in % of GDP?'},
#  {'answer': 'The most imported goods from India are petroleum oils.',
#   'category': 'International trade',
#   'choices': ['Diamonds', 'Spices', 'Petroleum oils'],
#   'question': 'The main EU imports of goods from India are:'}]
