# %% [markdown]
# # Poll
# - What is your experience with Big Data?
# - What is you expectation about this course?

# %% [markdown]
# # What is Big Data ?
# - Volume
# - Velocity
# - Variety

# %% [markdown]
# # Big Data Life Cycle

# %% [markdown]
# # Open Source Tools
