# %% [markdown]
# # Data is the new Oil

# %%
# %%html
# <iframe src="https://en.wikipedia.org/wiki/List_of_public_corporations_by_market_capitalization#2021" width="1000" height="600"></iframe>
# Out:
# <iframe src="https://en.wikipedia.org/wiki/List_of_public_corporations_by_market_capitalization#2021" width="1000" height="600"></iframe>

# %% [markdown]
# # What is Big Data ?

# %% [markdown]
# ## Volume
#
# <img src="https://i.insider.com/4dfb8533ccd1d5cb200d0000?width=1700&format=jpeg&auto=webp"/>

# %% [markdown]
# <img src="https://assets.weforum.org/editor/large_1wZFPPQxA3arZahkXNge_pYCgI7alwllw3o5S6fgqc8.png"/>

# %% [markdown]
# ## Velocity

# %% [markdown]
# <img src="https://mloapwwtsct7.i.optimole.com/A6Igeow.l1xK~43710/w:auto/h:auto/q:75/https://www.bondhighplus.com/wp-content/uploads/2020/05/Internet-Minute-2021.jpg" width="70%"/>

# %% [markdown]
# ## Variety

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/ee/Big_Data.png" width="70%"/>

# %% [markdown]
# ## (Veracity)
# "garbage in, garbage out"

# %% [markdown]
# ## (Value)
# store data in its raw form

# %% [markdown]
# # Data Types

# %% [markdown]
# ## Structured
# - Excel File
# - Database

# %% [markdown]
# ## Unstructured
# - Email
# - Image
# - Audio

# %% [markdown]
# ## Semi-Structured
# - JSON
# - HTML/XML

# %% [markdown]
# # History

# %% [markdown]
# ## Nutch = Google File System + MapReduce
# > Yahoo provided search over 1 billion pages at a time

# %%
# %%html
# <iframe src="https://en.wikipedia.org/wiki/Apache_Hadoop#History" width="90%" height="300"/>
# Out:
# <iframe src="https://en.wikipedia.org/wiki/Apache_Hadoop#History" width="90%" height="300"/>

# %% [markdown]
# ## Apache Software Foundation
# > The world's largest open source foundation

# %%
# %%html
# <iframe src="https://projects.apache.org/projects.html" width="90%" height="300"/>
# Out:
# <iframe src="https://projects.apache.org/projects.html" width="90%" height="300"/>

# %% [markdown]
# ## Big Tech Sponsors
# - Cloudera
# - Google
# - IBM
# - Meta (Facebook)
# - Microsoft
# - Twitter
# - Yahoo
# - ...

# %% [markdown]
# # Cloud providers

# %% [markdown]
# <img src="https://managecasa.com/wp-content/uploads/2020/11/buy-vs-rent-e1614009358449.jpg" width="70%"/>

# %% [markdown]
# ## Big Data Pipelines / Life Cycle

# %% [markdown]
# <img src="https://preview.redd.it/82cgd6zaebr61.png?width=640&crop=smart&auto=webp&s=012858296d9aee2af769615d70fff0c62d514308" width="80%"/>

# %% [markdown]
# ## Cloud Service Models
# - The right Big Data Platform depends on the problem you're trying to solve!

# %% [markdown]
# <img src="https://i.pinimg.com/originals/eb/a0/29/eba02996e9b4a92911f53ac8453a6882.png" width="80%"/>

# %% [markdown]
# - **Software as a Service (SaaS)** is a software licensing and delivery model in which software is licensed on a subscription basis and is centrally hosted.
# - **Function as a Service (FaaS)** is a category of cloud computing services that provides a platform allowing customers to develop, run, and manage application functionalities without the complexity of building and maintaining the infrastructure typically associated with developing and launching an app.
# - **Data as a Service (DaaS)** is a term used to describe cloud-based software tools used for working with data, such as managing data in a data warehouse or analyzing data with business intelligence.
# - **Platform as a Service (PaaS)** is a cloud computing model where a third-party provider delivers hardware and software tools to users over the internet.
# - **Storage as a Service (STaaS)** is the practice of using public cloud storage resources to store your data.
# - **Infrastructure as a Service (IaaS)** is a form of cloud computing that provides virtualized computing resources over the internet.

# %% [markdown]
# ## ❓ Poll
# - What Big Data problem are you trying to solve?
# - What is your experience with Big Data?
# - What is you expectation for this course?
