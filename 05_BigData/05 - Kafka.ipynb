# %% [markdown]
# # [Kafka](https://kafka.apache.org/)

# %% [markdown]
# ## Install

# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /usr/local/lib/python3.7/dist-packages (2.0.2)

# %%
# !curl -sSOL https://downloads.apache.org/kafka/3.0.0/kafka_2.13-3.0.0.tgz
# !tar -xzf kafka_2.13-3.0.0.tgz

# %% [markdown]
# ## Launch

# %% [markdown]
# Start Zookper server and Kafka broker

# %%
# !./kafka_2.13-3.0.0/bin/zookeeper-server-start.sh -daemon ./kafka_2.13-3.0.0/config/zookeeper.properties
# !./kafka_2.13-3.0.0/bin/kafka-server-start.sh -daemon ./kafka_2.13-3.0.0/config/server.properties
# !echo "Waiting for 10 secs until kafka and zookeeper services are up and running"
# !sleep 10
# Out:
# Waiting for 10 secs until kafka and zookeeper services are up and running

# %% [markdown]
# Check that both processes are running

# %%
# !ps -ef | grep kafka
# Out:
# root        8989       1  0 06:12 ?        00:00:07 java -Xmx512M -Xms512M -server -XX:+UseG1GC -XX:MaxGCPauseMillis=20 -XX:InitiatingHeapOccupancyPercent=35 -XX:+ExplicitGCInvokesConcurrent -XX:MaxInlineLevel=15 -Djava.awt.headless=true -Xlog:gc*:file=/content/kafka_2.13-3.0.0/bin/../logs/zookeeper-gc.log:time,tags:filecount=10,filesize=100M -Dcom.sun.management.jmxremote -Dcom.sun.management.jmxremote.authenticate=false -Dcom.sun.management.jmxremote.ssl=false -Dkafka.logs.dir=/content/kafka_2.13-3.0.0/bin/../logs -Dlog4j.configuration=file:./kafka_2.13-3.0.0/bin/../config/log4j.properties -cp /content/kafka_2.13-3.0.0/bin/../libs/activation-1.1.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/aopalliance-repackaged-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/argparse4j-0.7.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/audience-annotations-0.5.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/commons-cli-1.4.jar:/content/kafka_2.13-3.0.0/bin/../libs/commons-lang3-3.8.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-api-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-basic-auth-extension-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-file-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-json-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-mirror-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-mirror-client-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-runtime-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-transforms-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/hk2-api-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/hk2-locator-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/hk2-utils-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-annotations-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-core-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-databind-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-dataformat-csv-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-datatype-jdk8-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-jaxrs-base-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-jaxrs-json-provider-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-module-jaxb-annotations-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-module-scala_2.13-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.activation-api-1.2.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.annotation-api-1.3.5.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.inject-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.validation-api-2.0.2.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.ws.rs-api-2.1.6.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.xml.bind-api-2.3.2.jar:/content/kafka_2.13-3.0.0/bin/../libs/javassist-3.27.0-GA.jar:/content/kafka_2.13-3.0.0/bin/../libs/javax.servlet-api-3.1.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/javax.ws.rs-api-2.1.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jaxb-api-2.3.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-client-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-common-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-container-servlet-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-container-servlet-core-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-hk2-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-server-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-client-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-continuation-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-http-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-io-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-security-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-server-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-servlet-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-servlets-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-util-9 ...
# root        9339       1  1 06:12 ?        00:00:43 java -Xmx1G -Xms1G -server -XX:+UseG1GC -XX:MaxGCPauseMillis=20 -XX:InitiatingHeapOccupancyPercent=35 -XX:+ExplicitGCInvokesConcurrent -XX:MaxInlineLevel=15 -Djava.awt.headless=true -Xlog:gc*:file=/content/kafka_2.13-3.0.0/bin/../logs/kafkaServer-gc.log:time,tags:filecount=10,filesize=100M -Dcom.sun.management.jmxremote -Dcom.sun.management.jmxremote.authenticate=false -Dcom.sun.management.jmxremote.ssl=false -Dkafka.logs.dir=/content/kafka_2.13-3.0.0/bin/../logs -Dlog4j.configuration=file:./kafka_2.13-3.0.0/bin/../config/log4j.properties -cp /content/kafka_2.13-3.0.0/bin/../libs/activation-1.1.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/aopalliance-repackaged-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/argparse4j-0.7.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/audience-annotations-0.5.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/commons-cli-1.4.jar:/content/kafka_2.13-3.0.0/bin/../libs/commons-lang3-3.8.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-api-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-basic-auth-extension-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-file-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-json-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-mirror-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-mirror-client-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-runtime-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/connect-transforms-3.0.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/hk2-api-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/hk2-locator-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/hk2-utils-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-annotations-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-core-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-databind-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-dataformat-csv-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-datatype-jdk8-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-jaxrs-base-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-jaxrs-json-provider-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-module-jaxb-annotations-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jackson-module-scala_2.13-2.12.3.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.activation-api-1.2.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.annotation-api-1.3.5.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.inject-2.6.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.validation-api-2.0.2.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.ws.rs-api-2.1.6.jar:/content/kafka_2.13-3.0.0/bin/../libs/jakarta.xml.bind-api-2.3.2.jar:/content/kafka_2.13-3.0.0/bin/../libs/javassist-3.27.0-GA.jar:/content/kafka_2.13-3.0.0/bin/../libs/javax.servlet-api-3.1.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/javax.ws.rs-api-2.1.1.jar:/content/kafka_2.13-3.0.0/bin/../libs/jaxb-api-2.3.0.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-client-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-common-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-container-servlet-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-container-servlet-core-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-hk2-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jersey-server-2.34.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-client-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-continuation-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-http-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-io-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-security-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-server-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-servlet-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-servlets-9.4.43.v20210629.jar:/content/kafka_2.13-3.0.0/bin/../libs/jetty-util-9.4 ...
# root       10860   10091  0 07:15 ?        00:00:00 /bin/bash -c ps -ef | grep kafka
# root       10862   10860  0 07:15 ?        00:00:00 grep kafka

# %% [markdown]
# ## Create Topic

# %%
# !./kafka_2.13-3.0.0/bin/kafka-topics.sh --create --bootstrap-server 127.0.0.1:9092 --replication-factor 1 --partitions 1 --topic numberstream
# Out:
# Error while executing topic command : Topic 'numberstream' already exists.
# [2021-11-05 07:15:59,070] ERROR org.apache.kafka.common.errors.TopicExistsException: Topic 'numberstream' already exists.
#  (kafka.admin.TopicCommand$)

# %% [markdown]
# ## Create Producer

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer

# %%
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                         value_serializer=lambda x: dumps(x).encode('utf-8'))

# %%
for e in range(10):
  data = {'number' : e}
  producer.send('numberstream', value=data)
  sleep(2)

# %% [markdown]
# ## Create Consumer

# %%
from kafka import KafkaConsumer
from json import loads

# %%
consumer = KafkaConsumer('numberstream',
                         bootstrap_servers=['localhost:9092'],
                         auto_offset_reset='earliest',
                         auto_commit_interval_ms=1000,
                         enable_auto_commit=True,
                         group_id='my-group',
                         value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for message in consumer:
  print(f'Received {message.value}')
# Out:
# Received {'number': 7}
# Received {'number': 8}
# Received {'number': 9}
# Received {'number': 0}
# Received {'number': 1}
# Received {'number': 2}
# Received {'number': 3}
# Received {'number': 4}
# Received {'number': 5}
# Received {'number': 6}
# Received {'number': 7}
# Received {'number': 8}
# Received {'number': 9}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8e22754843bd> in <module>()
# ----> 1 for message in consumer:
#       2   print(f'Received {message.value}')
#
# /usr/local/lib/python3.7/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.7/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.7/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.7/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.7/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.7/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.7/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.7/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Run Producer & Consumer

# %%
for e in range(10):
  data = {'number' : e}
  producer.send('numberstream', value=data)

  sleep(2)

  for message in consumer:
    print(f'Received {message.value}')
    break
# Out:
# Received {'number': 0}
# Received {'number': 1}
# Received {'number': 2}
# Received {'number': 3}
# Received {'number': 4}
# Received {'number': 5}
# Received {'number': 6}
# Received {'number': 7}
# Received {'number': 8}
# Received {'number': 9}
